# %%
import pandas as pd

# %%
df = pd.read_csv("Test_box2.csv")
print(df.columns)
# Out:
# Index(['Name', 'Jersey #', 'Team', 'Opponent', 'didWin', 'Date', 'MIN', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'FGM', 'FGA', '3PM',
#        '3PA', 'FTM', 'FTA', 'PTS', 'FantasyPts'],
#       dtype='object')

# %%
display(df[['Name','Opponent', 'didWin', 'Date', 'MIN', 'OREB',
       'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'FGM', 'FGA', '3PM',
       '3PA', 'FTM', 'FTA', 'PTS', 'FantasyPts']])
# Out:
#                  Name                  Opponent  didWin      Date  MIN  OREB  \
# 0      Abigail Shoff          San Diego Toreros       1  01/23/25   18     1
# 1     Zeryhia Aokuso          San Diego Toreros       1  01/23/25   31     0
# 2        Jada Hunter          San Diego Toreros       1  01/23/25   27     0
# 3         Maia Jones          San Diego Toreros       1  01/23/25   37     0
# 4    Kennedy Johnson          San Diego Toreros       1  01/23/25   24     1
# ..                ...                       ...     ...       ...  ...   ...
# 321     McKelle Meek   Washington State Cougars       1  02/15/25   35     0
# 322     Lainey Spear   Washington State Cougars       1  02/15/25   13     0
# 323   Ella Zimmerman   Washington State Cougars       1  02/15/25    1     0
# 324      Rhyan Mogel   Washington State Cougars       1  02/15/25   16     0
# 325   Natalie Fraley   Washington State Cougars       1  02/15/25   10     0
#
# ...

# %%
import matplotlib.pyplot as plt

# Display basic statistics
print(df['FantasyPts'].describe())

# Plot distribution
plt.figure(figsize=(8, 5))
plt.hist(df['FantasyPts'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of FantasyPts')
plt.xlabel('FantasyPts')
plt.ylabel('Frequency')
plt.show()
# Out:
# count    326.000000
# mean      16.604294
# std       15.095588
# min      -13.000000
# 25%        3.000000
# 50%       14.000000
# 75%       26.000000
# max       66.000000
# Name: FantasyPts, dtype: float64
